# %% [markdown]
# # Import Statements

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import pandas as pd
import os
import tensorflow as tf

# Check if any GPU is detected
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))

gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        # Set TensorFlow to use only the first GPU
        tf.config.set_visible_devices(gpus[0], 'GPU')
        print(f"Using GPU: {gpus[0]}")
    except RuntimeError as e:
        print(e)
# Out:
# Num GPUs Available:  4
# Using GPU: PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %% [markdown]
# # Model Training

# %%
model = YOLO("yolo11s.pt")
results = model.train(data="coco.yaml", epochs=50, imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.3.111 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.74 🚀 Python-3.9.13 torch-2.6.0+cu124 CUDA:0 (NVIDIA RTX 6000 Ada Generation, 45486MiB)
# ...

# %%
best_model = YOLO('/home/exh4748/ProjectTortoise/NewRuns/runs/detect/train55/weights/best.pt')
metrics = best_model.val(data="coco.yaml")
# Out:
# Ultralytics 8.3.74 🚀 Python-3.9.13 torch-2.6.0+cu124 CUDA:0 (NVIDIA RTX 6000 Ada Generation, 45486MiB)
# YOLO11s summary (fused): 238 layers, 9,443,760 parameters, 0 gradients, 21.5 GFLOPs
# val: Scanning /home/exh4748/ProjectTortoise/Beta/datasets/coco/labels/val2017.cache... 4952 images, 48 backgrounds, 0 corrupt: 100%|██████████| 5000/5000 [0
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 313/313 [00:20<00:00, 15.29it/s]
#                    all       5000      36335      0.687      0.559      0.612      0.449
#                 person       2693      10777      0.803      0.711      0.797      0.573
#                bicycle        149        314      0.685      0.457      0.544      0.327
#                    car        535       1918      0.692      0.584      0.652      0.438
#             motorcycle        159        367      0.775      0.673       0.75      0.497
# ...

# %%
print("mAP50:", metrics.box.map50)        # mAP@0.5
print("mAP50-95:", metrics.box.map)       # mAP@0.5:0.95
print("Class-wise precision:", metrics.box.p)   # array of per-class precisions
print("Class-wise recall:", metrics.box.r)      # array of per-class recalls
# Out:
# mAP50: 0.6118299705656138
# mAP50-95: 0.4493614852787975
# Class-wise precision: [    0.80272     0.68509     0.69197     0.77476     0.79395     0.84088     0.86979     0.60819     0.66463     0.65355     0.91713     0.76146     0.78232     0.53508     0.73431     0.83587     0.79949     0.83123     0.72897     0.76387     0.73782     0.89597     0.84846     0.87133     0.52113     0.65346
#      0.55426     0.71438     0.65915      0.7953     0.69323     0.56982     0.73054     0.69803     0.61174     0.77201     0.78821     0.72319     0.74686     0.63263     0.74439     0.61333     0.67964     0.54217     0.48211     0.63711      0.5564     0.41739     0.57674     0.45921     0.52646     0.42536
# ...

# %%
print("Mean Precision:", metrics.box.p.mean())
print("Mean Recall:", metrics.box.r.mean())
# Out:
# Mean Precision: 0.6866335732207719
# Mean Recall: 0.5591718458484927
